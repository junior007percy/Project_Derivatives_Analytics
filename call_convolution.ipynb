# %%
#
# Call Option Pricing with Circular Convolution (Simple)
#
import math
import numpy as np
from convolution import revnp, convolution

# parameter Definitions
M = 4 # number of time steps
dt = 1.0 / M # length of time interval 
r = 0.05 # constant short rate
C = [49.18246976, 22.14027582, 0, 0, 0] # call payoff at maturity
q = 0.537808372 # martingale probability
qv = np.array([q, 1 - q, 0, 0, 0]) # probability vector filled with zeros

# Calculation
V = np.zeros((M + 1, M + 1), dtype=float)
V[M] = C

for t in range (M - 1, -1, -1):
    V[t] = convolution(V[t + 1], revnp(qv)) * math.exp(-r * dt)
    
print("Value of the Call Option %8.3f" % V[0, 0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 21
#      18 V[M] = C
#      20 for t in range (M - 1, -1, -1):
# ---> 21     V[t] = convolution(V[t + 1], revnp(qv)) * math.exp(-r * dt)
#      23 print("Value of the Call Option %8.3f" % V[0, 0])
#
# File c:\Project_Derivatives_Analytics_Python\Project_Derivatives_Analytics\convolution.py:32, in convolution(a, b)
#      30     raise ValueError('''Lengths of vectors do not match.''')
#      31 n = len(a)
# ---> 32 c = np.zeros(n, dtype=np.float)
#      33 for j in range (n):
#      34     s = 0
#
# File c:\Project_Derivatives_Analytics_Python\Project_Derivatives_Analytics\projectenv\Lib\site-packages\numpy\__init__.py:791, in __getattr__(attr)
#     786     warnings.warn(
#     787         f"In the future `np.{attr}` will be defined as the "
#     788         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     790 if attr in __former_attrs__:
# --> 791     raise AttributeError(__former_attrs__[attr], name=None)
#     793 if attr in __expired_attributes__:
#     794     raise AttributeError(
#     795         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     796         f"{__expired_attributes__[attr]}",
#     797         name=None
#     798     )
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
